# %%
import tensorflow as tf 
tf.config.optimizer.set_jit(False)
import numpy as np 
import matplotlib.pyplot as plt 

print(tf.__version__)
# Out:
# 2.17.0

# %%
import tensorflow as tf
import torch

print("=== TensorFlow ===")
print("GPU Available ✔️" if tf.config.list_physical_devices('GPU') else "GPU NOT Available ❌")

print("\n=== PyTorch ===")
print("GPU Available ✔️" if torch.cuda.is_available() else "GPU NOT Available ❌")
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# === TensorFlow ===
# GPU Available ✔️
#
# === PyTorch ===
# GPU Available ✔️
# NVIDIA GeForce RTX 5070 Ti Laptop GPU

# %%
X = tf.range(-10, 10, delta=3, dtype=tf.float32)
y = tf.range(0, 20, delta=3, dtype=tf.float32)

# %%
plt.scatter(X, y)

# %%
y == X + 50
# Out:
# <tf.Tensor: shape=(7,), dtype=bool, numpy=array([False, False, False, False, False, False, False])>

# %%
house_info = tf.constant(['bedroom', 'bathroom', 'garage'])
house_price = tf.constant([975350])

house_info, house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([975350], dtype=int32)>)

# %%
input_shape = X[0].shape
output_shape = y[0].shape

input_shape, output_shape
# Out:
# (TensorShape([]), TensorShape([]))

# %%
X[0].ndim, y[0].ndim
# Out:
# (0, 0)

# %%
# Set random sreversed
tf.random.set_seed(42)

# 2. Create a model using the Sequential Apiabs

model = tf.keras.Sequential([
    # tf.keras.layers.Dense(50, activation='relu'),
    tf.keras.layers.Dense(50, activation=None),
    tf.keras.layers.Dense(1)
])

# 3. Compile the mmodel

# model.compile(loss=tf.keras.losses.mae,
#              optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), 
#              metrics=['mae', 'mse'])

model.compile(loss=tf.keras.losses.mae,
             optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), 
             metrics=['mae', 'mse'])

# 4. Fit the model 

model.fit(tf.expand_dims(X, axis=-1), y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 918ms/step - loss: 9.1158 - mae: 9.1158 - mse: 111.2452
# Epoch 2/100
# 1/1 [==============================] - 0s 9ms/step - loss: 9.0146 - mae: 9.0146 - mse: 117.7544
# Epoch 3/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.8530 - mae: 8.8530 - mse: 113.2491
# Epoch 4/100
# 1/1 [==============================] - 0s 5ms/step - loss: 8.8439 - mae: 8.8439 - mse: 106.8480
# Epoch 5/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.7986 - mae: 8.7986 - mse: 103.2726
# Epoch 6/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.7148 - mae: 8.7148 - mse: 101.2846
# Epoch 7/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.6021 - mae: 8.6021 - mse: 100.3965
# Epoch 8/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.4662 - mae: 8.4662 - mse: 100.4294
# Epoch 9/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.3712 - mae: 8.3712 - mse: 101.3481
# Epoch 10/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.3085 - mae: 8.3085 - mse: 99.9575
# Epoch 11/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.1816 - mae: 8.1816 - mse: 96.8193
# Epoch 12/100
# 1/1 [==============================] - 0s 7ms/step - loss: 8.0616 - mae: 8.0616 - mse: 92.4757
# Epoch 13/100
# 1/1 [==============================] - 0s 4ms/step - loss: 7.9757 - mae: 7.9757 - mse: 89.1631
# Epoch 14/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7
100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6543 - mae: 0.6543 - mse: 0.5826
# Epoch 83/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5318 - mae: 0.5318 - mse: 0.3746
# Epoch 84/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2178 - mae: 0.2178 - mse: 0.0670
# Epoch 85/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2839 - mae: 0.2839 - mse: 0.1196
# Epoch 86/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3488 - mae: 0.3488 - mse: 0.1757
# Epoch 87/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1786 - mae: 0.1786 - mse: 0.0470
# Epoch 88/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2415 - mae: 0.2415 - mse: 0.0786
# Epoch 89/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3177 - mae: 0.3177 - mse: 0.1345
# Epoch 90/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1266 - mae: 0.1266 - mse: 0.0245
# Epoch 91/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2614 - mae: 0.2614 - mse: 0.0907
# Epoch 92/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3189 - mae: 0.3189 - mse: 0.1347
# Epoch 93/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1324 - mae: 0.1324 - mse: 0.0253
# Epoch 94/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2631 - mae: 0.2631 - mse: 0.0953
# Epoch 95/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3306 - mae: 0.3306 - mse: 0.1453
# Epoch 96/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1321 - mae: 0.1321 - mse: 0.0232
# Epoch 97/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2998 - mae: 0.2998 - mse: 0.1205
# Epoch 98/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4321 - mae: 0.4321 - mse: 0.2513
# Epoch 99/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3004 - mae: 0.3004 - mse: 0.1270
# Epoch 100/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1047 - mae: 0.1047 - mse: 0.0167

# %%
model.predict([10])
# Out:
# 1/1 [==============================] - 0s 44ms/step
# array([[20.681547]], dtype=float32)

# %%
X
# Out:
# <tf.Tensor: shape=(7,), dtype=float32, numpy=array([-10.,  -7.,  -4.,  -1.,   2.,   5.,   8.], dtype=float32)>

# %% [markdown]
# # Common ways to improve a deep model
#
# 1. Adding layers
# 2. Increase the number of hidden units
# 3. Change the activation functions
# 4. Change the optimization functions
# 5. Change the learning rate
# 6. Fitting on more data
# 7. Fitting for longer (epochs)

# %% [markdown]
# # Evaluating a model
# "Visualize, visualize, visualize"
#
# It is a good idea to visualize
# 1. Data
# 2. Model itself
# 3. Training - how does a model while it learns
# 4. The predictions of the model - predictions vs ground truth

# %%
# Work on a bigger data sget_ipython

X = tf.range(-100, 100, delta=4)
y = X + 10 
X, y
# Out:
# (<tf.Tensor: shape=(50,), dtype=int32, numpy=
#  array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#          -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#          -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#           32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#           76,   80,   84,   88,   92,   96], dtype=int32)>,
#  <tf.Tensor: shape=(50,), dtype=int32, numpy=
#  array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#         -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#          14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#          66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>)

# %%
plt.scatter(X, y)

# %%
plt.plot(X, y)

# %% [markdown]
# # Three sets
# 1. Training - %70-%80
# 2. Validation Set %10-%15
# 3. Test Set %10 - %15

# %%
# dataset = tf.data.Dataset.from_tensor_slices((X, y))
# dataset = dataset.shuffle(buffer_size=len(X), seed=42)

# train_size = int(0.8 * len(X))
# train_ds = dataset.take(train_size)
# test_ds = dataset.skip(train_size)

# %%
from sklearn.model_selection import train_test_split

X_np = X.numpy()
y_np = y.numpy()
X_train, X_test, y_train, y_test = train_test_split(X_np, y_np, test_size=0.2, random_state=42)

X_train = tf.constant(X_train, dtype=tf.float32)
X_test = tf.constant(X_test, dtype=tf.float32) 
y_train = tf.constant(y_train, dtype=tf.float32) 
y_test = tf.constant(y_test, dtype=tf.float32)

# %%
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=50, verbose=0)

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 69ms/step - loss: 0.5739 - mae: 0.5739 - mse: 0.4550
# [0.5738515853881836, 0.5738515853881836, 0.4549790322780609]

# %%
# Visualize data

# %%
plt.figure(figsize=(10, 7))
plt.scatter(X_train, y_train, c='b', label="Training data")
plt.scatter(X_test, y_test, c='g', label="Test Data")
plt.legend();

# %%
X_train.shape
# Out:
# TensorShape([40])

# %%
# 1 Create a model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=[1])
])

# 2. Compile the model
model.compile(loss=tf.keras.losses.mae, 
             optimizer=tf.keras.optimizers.SGD(), 
             metrics=['mae', 'mse'])

# # 3. Fit the model 
# model.fit(X_train, y_train, epochs=100)

# %%
## 1. Visualize the model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Create model which builds automatically by defining the input_shape argument
tf.random.set_seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=[1]),
    # tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(100, activation='relu')
])

model.compile(loss=tf.keras.losses.mae, 
             optimizer=tf.keras.optimizers.SGD(), 
             metrics=['mae', 'mse'])


model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 1)                 2
#
#  dense_4 (Dense)             (None, 100)               200
#
# =================================================================
# Total params: 202 (808.00 Byte)
# Trainable params: 202 (808.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100, verbose=0)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 1)                 2
#
#  dense_4 (Dense)             (None, 100)               200
#
# =================================================================
# Total params: 202 (808.00 Byte)
# Trainable params: 202 (808.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 61ms/step - loss: 15.7778 - mae: 15.7778 - mse: 407.6968
# [15.777801513671875, 15.777801513671875, 407.69683837890625]

# %%
# total_param : total number of parameters in the model 
# trainable parameters : the parameters (patterns) the model update as it trains. 
# non trainable parameters : When we import a pre built/trained model we want to freeze parameters transferred model

# %%
# Weights and biases - Trainable/Learnable params

# %%
from tensorflow.keras.utils import plot_model

plot_model(model=model, show_shapes=True)

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, input_shape=[1], name="input_layer"),
    tf.keras.layers.Dense(1, name="output_layer")
], name="model_1")

model.compile(loss=tf.keras.losses.mae, 
             optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
             metrics=[
                tf.keras.losses.MeanAbsoluteError(name='MAE'),
                tf.keras.losses.MeanSquaredError(name="MSE"),
                tf.keras.losses.Huber(name="HUBER")
            ])

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (Dense)         (None, 10)                20
#
#  output_layer (Dense)        (None, 1)                 11
#
# =================================================================
# Total params: 31 (124.00 Byte)
# Trainable params: 31 (124.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100, verbose=0)

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 91ms/step - loss: 10.7089 - MAE: 10.7089 - MSE: 131.9062 - HUBER: 10.2089
# [10.70891284942627, 10.70891284942627, 131.90615844726562, 10.20891284942627]

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (Dense)         (None, 10)                20
#
#  output_layer (Dense)        (None, 1)                 11
#
# =================================================================
# Total params: 31 (124.00 Byte)
# Trainable params: 31 (124.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
plot_model(model=model, show_shapes=True)

# %%
y_pred = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 23ms/step

# %%
def plot_pred_vs_true(X_train, 
                      y_train, 
                      X_test, 
                      y_true, 
                      y_pred):
    plt.figure(figsize=(10, 7))
    plt.scatter(X_test, y_pred, c='b', label="Predictions")
    plt.scatter(X_test, y_true, c="r", label="Testing Data")
    plt.scatter(X_train, y_train, c='g', label="Training Data")
    plt.legend();

# %%
plot_pred_vs_true(X_train, y_train, X_test, y_test, y_pred)

# %% [markdown]
# ### Evaluating the model's predictions with regression evaluation metrics
#
# There are two main metrics to evaluate a regression model.png
#
# 1. Mean absolute error `mae` On average how wrong our predictions
# 2. MSE - Mean Square Error `mse` Square the avarege error
# 3. Huber - Combination of MAE and MSE

# %%
model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 17ms/step - loss: 10.7089 - MAE: 10.7089 - MSE: 131.9062 - HUBER: 10.2089
# [10.70891284942627, 10.70891284942627, 131.90615844726562, 10.20891284942627]

# %%
mae = tf.reduce_mean(tf.abs(y_test - tf.constant(y_pred)))
print(mae.numpy())
# Out:
# 49.88499

# %%
tf.reduce_mean((tf.metrics.mean_absolute_error(y_test, tf.constant(y_pred)))).numpy()
# Out:
# 49.884987

# %%
y_pred = tf.constant(y_pred)
y_test = tf.reshape(y_test, shape=(10, 1))
y_test, y_pred
# Out:
# (<tf.Tensor: shape=(10, 1), dtype=float32, numpy=
#  array([[-38.],
#         [ 66.],
#         [ 30.],
#         [ 90.],
#         [-22.],
#         [102.],
#         [ 14.],
#         [ 10.],
#         [ 38.],
#         [-14.]], dtype=float32)>,
#  <tf.Tensor: shape=(10, 1), dtype=float32, numpy=
#  array([[-42.621914  ],
#         [ 51.727962  ],
#         [ 19.068392  ],
#         [ 73.501015  ],
#         [-28.106544  ],
#         [ 84.38754   ],
#         [  4.553026  ],
#         [  0.92418486],
#         [ 26.326075  ],
#         [-20.848864  ]], dtype=float32)>)

# %%
mae = tf.reduce_mean(tf.abs(y_test - y_pred))
print(mae.numpy())
# Out:
# 10.708913

# %%
(tf.metrics.mean_absolute_error(y_test, y_pred)).numpy()
# Out:
# array([ 4.621914 , 14.2720375, 10.931608 , 16.498985 ,  6.1065445,
#        17.612457 ,  9.446974 ,  9.075815 , 11.673925 ,  6.8488636],
#       dtype=float32)

# %%
# y_test = tf.reshape(y_test, shape=(10,))
# y_pred = tf.reshape(y_pred, shape=(10,))
y_pred = tf.squeeze(y_pred)
y_test = tf.squeeze(y_test)

y_test, y_pred
# Out:
# (<tf.Tensor: shape=(10,), dtype=float32, numpy=
#  array([-38.,  66.,  30.,  90., -22., 102.,  14.,  10.,  38., -14.],
#        dtype=float32)>,
#  <tf.Tensor: shape=(10,), dtype=float32, numpy=
#  array([-42.621914  ,  51.727962  ,  19.068392  ,  73.501015  ,
#         -28.106544  ,  84.38754   ,   4.553026  ,   0.92418486,
#          26.326075  , -20.848864  ], dtype=float32)>)

# %%
tf.metrics.mean_absolute_error(y_test, y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.708913>

# %%
tf.metrics.mean_squared_error(y_pred, y_test)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=131.90616>

# %%
huber = tf.keras.losses.Huber()
huber(y_true=y_test, y_pred=y_pred).numpy()
# Out:
# 10.208913

# %% [markdown]
# ## Running experiments to improve the model
# 1. 1 Layer - 100 epochs
# 2. 2 layers -- 100 epochs
# 3. 2 layers -- 500 epochs
# 4. 2 layers Adam - lr = 0.001 100 Epochs
# 5. 2 layers Adam - lr = 0.001 500 epochs
# 6. 2 layers Adam -lr = 0.01 100 epochs

# %%
def calculate_mae_mse(y_true=y_test, 
                     y_pred=y_pred):
    return tf.metrics.mean_absolute_error(y_true, tf.squeeze(y_pred)).numpy(), tf.metrics.mean_squared_error(y_true, tf.squeeze(y_pred)).numpy()

# %%
# model_1

model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
], name='model_1')

model_1.compile(loss=tf.keras.losses.mae, 
             optimizer=tf.keras.optimizers.SGD(), 
             metrics=['mae', 'mse'])

model_1.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100, verbose=0)

# %%
y_preds_1 = model_1.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
y_preds_1
# Out:
# array([[-30.740053 ],
#        [ 38.416    ],
#        [ 14.4773655],
#        [ 54.375088 ],
#        [-20.10066  ],
#        [ 62.354633 ],
#        [  3.837973 ],
#        [  1.1781249],
#        [ 19.797064 ],
#        [-14.780964 ]], dtype=float32)

# %%
mae_1, mse_1 = calculate_mae_mse(y_true=y_test, y_pred=y_preds_1)
mae_1, mse_1
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=16.550402>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=441.2082>)

# %%
tf.random.set_seed(42)

model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation='relu'),  # first layer
    tf.keras.layers.Dense(1)                        # output layer
], name='model_2')

model_2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.SGD(),
    metrics=[
        tf.keras.losses.MeanAbsoluteError(name='mae'),
        tf.keras.losses.MeanSquaredError(name='mse'),
        tf.keras.losses.Huber(name='Huber')
    ]
)

model_2.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100, verbose=0)

# %%
y_preds_2 = model_2.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 12ms/step

# %%
X_test
# Out:
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([-48.,  56.,  20.,  80., -32.,  92.,   4.,   0.,  28., -24.],
#       dtype=float32)>

# %%
y_preds_2
# Out:
# array([[-11.689414  ],
#        [ 50.787758  ],
#        [ 18.468554  ],
#        [ 72.3339    ],
#        [ -7.6369996 ],
#        [ 83.106964  ],
#        [  4.1044607 ],
#        [  0.51351607],
#        [ 25.6506    ],
#        [ -5.6107917 ]], dtype=float32)

# %%
mae_2, mse_2 = calculate_mae_mse(y_true=y_test, y_pred=y_preds_2)
mae_2, mse_2
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=14.409703>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=234.27689>)

# %%
# model_3 -- 2 layers -- 500 epochs

tf.random.set_seed(42)

model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(1)
], name='model_3')

model_3.compile(loss=tf.keras.losses.mae, 
               optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
               metrics=[
                   tf.keras.losses.MeanAbsoluteError(name='mae'),
                   tf.keras.losses.MeanSquaredError(name='mse'), 
                   tf.keras.losses.Huber(name='huber')
               ])

model_3.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100, verbose=0)

# %%
y_preds_3 = model_3.predict(X_test)
y_preds_3
# Out:
# 1/1 [==============================] - 0s 25ms/step
# array([[-41.699078 ],
#        [ 64.61294  ],
#        [ 23.880953 ],
#        [ 91.7676   ],
#        [-27.726818 ],
#        [105.34493  ],
#        [  5.77206  ],
#        [  1.1210856],
#        [ 32.932507 ],
#        [-20.740686 ]], dtype=float32)

# %%
mae_3, mse_3 = calculate_mae_mse(y_pred=y_preds_3)
mae_3, mse_3
# Out:
# (5.0959573, 31.780972)

# %%
#model_4 -->2 layers Adam - lr = 0.001 500 Epochs

tf.random.set_seed(42)

model_4 = tf.keras.Sequential([
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(1)
], name='model_4')

model_4.compile(loss=tf.keras.losses.mae, 
               optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), 
               metrics=[
                   tf.keras.losses.MeanAbsoluteError(name='mae'),
                   tf.keras.losses.MeanSquaredError(name='mse'),
                   tf.keras.losses.Huber(name='huber')
               ])

model_4.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=500, verbose=0) 
model_4.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_26 (Dense)            (None, 100)               200
#
#  dense_27 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 301 (1.18 KB)
# Trainable params: 301 (1.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
y_preds_4 = model_4.predict(X_test)
y_preds_4
# Out:
# 1/1 [==============================] - 0s 24ms/step
# array([[-38.200153],
#        [ 66.26291 ],
#        [ 30.102621],
#        [ 90.36977 ],
#        [-22.128914],
#        [102.4232  ],
#        [ 14.03138 ],
#        [ 10.013569],
#        [ 38.13824 ],
#        [-14.093294]], dtype=float32)

# %%
mae_4, mse_4 = calculate_mae_mse(y_pred=y_preds_4)
mae_4, mse_4
# Out:
# (0.17640495, 0.04811429)

# %%
plot_pred_vs_true(X_train=X_train,
                  y_train=y_train,
                 X_test=X_test, 
                 y_true=y_test, 
                 y_pred=y_preds_4)

# %%
plot_pred_vs_true(X_train=X_train,
                  y_train=y_train,
                 X_test=X_test, 
                 y_true=y_test, 
                 y_pred=y_preds_1)

# %%
plot_pred_vs_true(X_train=X_train,
                  y_train=y_train,
                 X_test=X_test, 
                 y_true=y_test, 
                 y_pred=y_preds_2)

# %%
plot_pred_vs_true(X_train=X_train,
                  y_train=y_train,
                 X_test=X_test, 
                 y_true=y_test, 
                 y_pred=y_preds_3)

# %%
# model_5 - 2 layers , Adam 0.01, 100 epochs

tf.random.set_seed(42)

model_5 = tf.keras.Sequential([
    tf.keras.layers.Dense(100), 
    tf.keras.layers.Dense(1)
], name='model_5')

model_5.compile(loss=tf.keras.losses.mae, 
               optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), 
               metrics=[
                   tf.keras.losses.MeanAbsoluteError(name='mae'), 
                   tf.keras.losses.MeanSquaredError(name='mse'), 
                   tf.keras.losses.Huber(name='huber')
               ])

model_5.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100, verbose=0)
model_5.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 100)               200
#
#  dense_29 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 301 (1.18 KB)
# Trainable params: 301 (1.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
y_preds_5 = model_5.predict(X_test)
y_preds_5
# Out:
# 1/1 [==============================] - 0s 10ms/step
# array([[-39.790424],
#        [ 68.07093 ],
#        [ 30.73431 ],
#        [ 92.96201 ],
#        [-23.196367],
#        [105.40756 ],
#        [ 14.140254],
#        [  9.99174 ],
#        [ 39.031334],
#        [-14.899341]], dtype=float32)

# %%
mae_5, mse_5 = calculate_mae_mse(y_pred=y_preds_5)
mae_5, mse_5
# Out:
# (1.4240797, 3.1742084)

# %%
plot_pred_vs_true(X_train=X_train,
                  y_train=y_train,
                 X_test=X_test, 
                 y_true=y_test, 
                 y_pred=y_preds_5)
